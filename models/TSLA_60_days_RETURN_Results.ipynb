# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\riama\anaconda3\lib\site-packages (0.1.70)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\riama\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\riama\anaconda3\lib\site-packages (from yfinance) (4.6.1)
# Requirement already satisfied: requests>=2.26 in c:\users\riama\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\riama\anaconda3\lib\site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\riama\anaconda3\lib\site-packages (from yfinance) (1.22.3)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\riama\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\riama\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.25.11)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\riama\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riama\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\riama\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\riama\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\riama\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)

# %%
import math
import pandas_datareader as web
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
import yfinance as yf


plt.style.use('fivethirtyeight')

# %%
import datetime

now = datetime.datetime.now()
print("Last updated:", now.strftime("%Y-%m-%d" + " at "+ "%H:%M:%S"))
# Out:
# Last updated: 2022-08-02 at 20:21:18

# %%
start = datetime.datetime(2012, 11, 4) # START ON January 1 2016
end = datetime.datetime(2022,7,27)
# end = datetime.date.today() # LOOK AT STOCKS TILL current date

tickers = ['TSLA','AAPL']
df_map = {}

for tick in tickers:
    data_source='google'
    stock =yf.download(tick,start, end)
    df_map[tick] = stock
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
TSLA_AAPL_stocks = pd.concat(df_map,axis = 1,keys = tickers)
TSLA_AAPL_stocks.head()
# Out:
#              TSLA                                                AAPL  \
#              Open   High    Low  Close Adj Close    Volume       Open
# Date
# 2012-11-05  5.960  6.316  5.866  6.300     6.300  10244500  20.840000
# 2012-11-06  6.122  6.240  5.990  6.230     6.230  11620000  21.079643
# 2012-11-07  6.200  6.410  6.162  6.308     6.308   8572500  20.494286
# 2012-11-08  6.202  6.376  6.188  6.262     6.262   6370000  20.022499
# 2012-11-09  6.120  6.186  5.970  6.064     6.064   4315000  19.300714
#
#
#                  High        Low      Close  Adj Close      Volume
# Date
# 2012-11-05  20.991785  20.628571  20.879286  17.928808   529135600
# 2012-11-06  21.097857  20.717501  20.816071  17.874529   374917200
# 2012-11-07  20.519285  19.848213  19.928572  17.190598   793648800
# 2012-11-08  20.079643  19.117500  19.205357  16.566753  1056146000
# 2012-11-09  19.817142  19.061428  19.537857  16.853567   929913600

# %%
df = pd.DataFrame(TSLA_AAPL_stocks) #KO_PEP_stocks dataframe
for tick in tickers:
    df[tick+'_Return'] = TSLA_AAPL_stocks[tick]['Close'].pct_change()
df.head()
# Out:
#              TSLA                                                AAPL  \
#              Open   High    Low  Close Adj Close    Volume       Open
# Date
# 2012-11-05  5.960  6.316  5.866  6.300     6.300  10244500  20.840000
# 2012-11-06  6.122  6.240  5.990  6.230     6.230  11620000  21.079643
# 2012-11-07  6.200  6.410  6.162  6.308     6.308   8572500  20.494286
# 2012-11-08  6.202  6.376  6.188  6.262     6.262   6370000  20.022499
# 2012-11-09  6.120  6.186  5.970  6.064     6.064   4315000  19.300714
#
#                                                                     \
#                  High        Low      Close  Adj Close      Volume
# Date
# 2012-11-05  20.991785  20.628571  20.879286  17.928808   529135600
# 2012-11-06  21.097857  20.717501  20.816071  17.874529   374917200
# 2012-11-07  20.519285  19.848213  19.928572  17.190598   793648800
# 2012-11-08  20.079643  19.117500  19.205357  16.566753  1056146000
# 2012-11-09  19.817142  19.061428  19.537857  16.853567   929913600
#
#            TSLA_Return AAPL_Return
#
# Date
# 2012-11-05         NaN         NaN
# 2012-11-06   -0.011111   -0.003028
# 2012-11-07    0.012520   -0.042635
# 2012-11-08   -0.007292   -0.036290
# 2012-11-09   -0.031619    0.017313

# %%
df.columns = ['TSLA_Open','TSLA_High','TSLA_Low','TSLA_Close','TSLA_AdjClose','TSLA_Volume',
                  'AAPL_Open','AAPL_High','AAPL_Low','AAPL_Close','AAPL_AdjClose','AAPL_Volume', 'TSLA_Return', 'AAPL_Return']

df.head()
# Out:
#             TSLA_Open  TSLA_High  TSLA_Low  TSLA_Close  TSLA_AdjClose  \
# Date
# 2012-11-05      5.960      6.316     5.866       6.300          6.300
# 2012-11-06      6.122      6.240     5.990       6.230          6.230
# 2012-11-07      6.200      6.410     6.162       6.308          6.308
# 2012-11-08      6.202      6.376     6.188       6.262          6.262
# 2012-11-09      6.120      6.186     5.970       6.064          6.064
#
#             TSLA_Volume  AAPL_Open  AAPL_High   AAPL_Low  AAPL_Close  \
# Date
# 2012-11-05     10244500  20.840000  20.991785  20.628571   20.879286
# 2012-11-06     11620000  21.079643  21.097857  20.717501   20.816071
# 2012-11-07      8572500  20.494286  20.519285  19.848213   19.928572
# 2012-11-08      6370000  20.022499  20.079643  19.117500   19.205357
# 2012-11-09      4315000  19.300714  19.817142  19.061428   19.537857
#
#             AAPL_AdjClose  AAPL_Volume  TSLA_Return  AAPL_Return
# Date
# 2012-11-05      17.928808    529135600          NaN          NaN
# 2012-11-06      17.874529    374917200    -0.011111    -0.003028
# 2012-11-07      17.190598    793648800     0.012520    -0.042635
# 2012-11-08      16.566753   1056146000    -0.007292    -0.036290
# 2012-11-09      16.853567    929913600    -0.031619     0.017313

# %%
plt.figure(figsize = (16,8))
plt.plot(df["TSLA_Return"])
plt.title('Tesla stock price history: RETURN')
plt.ylabel('Price (USD)')
plt.xlabel('Days')
plt.legend(['Return'], loc='upper left')
plt.show()

# %%
df.drop(index=df.index[0], 
        axis=0, 
        inplace=True)

# %%
data = df.filter(['TSLA_Return'])
dataset = data.values

#Get number of rows to train the model on
training_data_len = math.ceil(len(dataset)* .8)

training_data_len
# Out:
# 1957

# %%
data
# Out:
#             TSLA_Return
# Date
# 2012-11-06    -0.011111
# 2012-11-07     0.012520
# 2012-11-08    -0.007292
# 2012-11-09    -0.031619
# 2012-11-12     0.024736
# ...                 ...
# 2022-07-20     0.008023
# 2022-07-21     0.097805
# 2022-07-22     0.001975
# 2022-07-25    -0.013995
# 2022-07-26    -0.035664
#
# [2446 rows x 1 columns]

# %%
#Scale the data
scaler = MinMaxScaler(feature_range = (0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.43890547],
#        [0.49089033],
#        [0.44730624],
#        ...,
#        [0.4676932 ],
#        [0.43256183],
#        [0.38489382]])

# %% [markdown]
# ## Trying to predict using 60 days as timestep

# %%
train_data = scaled_data[0:training_data_len  , : ]

x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<=60:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.43890547, 0.49089033, 0.44730624, 0.39379086, 0.51776375,
#        0.50158155, 0.44734176, 0.42409039, 0.5361527 , 0.53796585,
#        0.46869402, 0.42801746, 0.44031328, 0.47293349, 0.45516775,
#        0.53724637, 0.49380036, 0.47183673, 0.51538453, 0.41759777,
#        0.45101867, 0.47574719, 0.48086899, 0.48909985, 0.50852862,
#        0.46210105, 0.36040624, 0.47643855, 0.50173638, 0.47549849,
#        0.46462004, 0.45190731, 0.43587417, 0.48146442, 0.41906905,
#        0.46989726, 0.43265888, 0.50639142, 0.56012285, 0.42664272,
#        0.43993895, 0.45951123, 0.42106824, 0.46073558, 0.45615479,
#        0.42267115, 0.48674367, 0.5056783 , 0.47632657, 0.48141129,
#        0.47230618, 0.50604503, 0.51398376, 0.52384373, 0.46275351,
#        0.52580981, 0.45872066, 0.43842249, 0.46276177, 0.50967909])]
# [0.43118344312364343]

# %%
# converting into numpy sequences to train the LSTM model
x_train, y_train = np.array(x_train), np.array(y_train) 
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
print('Number of rows and columns: ', x_train.shape)
# Out:
# Number of rows and columns:  (1897, 60, 1)

# %%
x_train.shape
# Out:
# (1897, 60, 1)

# %%
model = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences = False))

model.add(Dense(25))
model.add(Dense(1))



model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(x_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 6s 35ms/step - loss: 0.0240
# Epoch 2/50
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0059
# Epoch 3/50
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0061
# Epoch 4/50
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0061
# Epoch 5/50
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0061
# Epoch 6/50
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0061
# Epoch 7/50
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0059
# Epoch 46/50
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0059
# Epoch 47/50
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0058
# Epoch 48/50
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0058
# Epoch 49/50
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0059
# Epoch 50/50
# 60/60 [==============================] - 3s 45ms/step - loss: 0.0059

# %%
# # We add the LSTM layer and later add a few Dropout layers to prevent overfitting.
# # Building a LTSM model with 50 neurons and 4 hidden layers. We add the LSTM layer with the following arguments:
# # 50 units which is the dimensionality of the output space
# # return_sequences=True which determines whether to return the last output in the output sequence, or the full sequence input_shape as the shape of our training set.
# # When defining the Dropout layers, we specify 0.2, meaning that 20% of the layers will be dropped.
# # Thereafter, we add the Dense layer that specifies the output of 1 unit.
# # After this, we compile our model using the popular adam optimizer and set the loss as the mean_squarred_error.

# model = Sequential()

# #Adding the first LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
# model.add(Dropout(0.2))

# # Adding a second LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))

# # Adding a fourth LSTM layer and some Dropout regularisation
# model.add(LSTM(units = 50))
# model.add(Dropout(0.2))

# # Adding the output layer
# model.add(Dense(units = 1))

# # Compiling the RNN
# model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# # Fitting the RNN to the Training set
# model.fit(x_train, y_train, epochs = 50, batch_size = 32)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Getting the predicted stock price
test_data = scaled_data[training_data_len - 60: , : ]

#Create the x_test and y_test data sets
x_test = []
y_test = dataset[training_data_len : , : ]
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i,0])

# Convert x_test to a numpy array
x_test = np.array(x_test)

# %%
#Reshape the data into the shape accepted by the LSTM
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print('Number of rows and columns: ', x_test.shape)
# Out:
# Number of rows and columns:  (489, 60, 1)

# %%
# Making predictions using the test dataset
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
predictions
# Out:
# array([[-1.89395563e-03],
#        [-1.02973345e-03],
#        [-4.98806708e-04],
#        [-3.74819967e-04],
#        [-2.10102280e-06],
#        [ 2.20809598e-04],
#        [ 7.59867908e-05],
#        [-1.12350615e-04],
#        [ 6.85898558e-05],
#        [ 2.56818865e-04],
#        [ 9.31108370e-05],
#        [ 6.27641159e-04],
#        [ 4.03755112e-04],
#        [-2.96136044e-04],
#        [-1.40071823e-03],
#        [-1.86157716e-03],
#        [-3.61581659e-03],
#        [-3.74893425e-03],
#        [-3.70441726e-03],
#        [-3.69135733e-03],
#        [-2.86867144e-03],
#        [-2.03390140e-03],
#        [-2.10288516e-03],
#        [-2.08362076e-03],
#        [-2.25310004e-03],
#        [-2.22974410e-03],
#        [-2.28547864e-03],
#        [-2.37437733e-03],
#        [-2.32034991e-03],
#        [-2.38117808e-03],
#        [-2.74427840e-03],
#        [-3.14921327e-03],
#        [-3.11095500e-03],
#        [-3.24434368e-03],
#        [-3.24949180e-03],
#        [-2.99390452e-03],
#        [-2.85618077e-03],
#        [-2.77988124e-03],
#        [-2.84772716e-03],
#        [-2.78223841e-03],
#        [-2.57393206e-03],
#        [-2.44257529e-03],
#        [-2.41781049e-03],
#        [-2.44561001e-03],
#        [-2.47056456e-03],
#        [-2.32991436e-03],
#        [-2.28303997e-03],
#        [-2.29119556e-03],
#        [-2.49711773e-03],
#        [-2.56656203e-03],
#        [-2.60918261e-03],
#        [-2.55504670e-03],
#        [-2.54805619e-03],
#        [-2.55504670e-03],
#        [-2.84629106e-03],
#        [-2.92055844e-03],
#        [-2.84675159e-03],
#        [-2.80908961e-03],
#        [-2.62568356e-03],
#        [-2.41258112e-03],
#        [-2.45633954e-03],
#        [-2.47565843e-03],
#        [-2.55501969e-03],
#        [-2.61552283e-03],
#        [-2.60793627e-03],
#        [-2.63226754e-03],
#        [-2.64855172e-03],
#        [-2.58577242e-03],
#        [-2.64784717e-03],
#        [-2.64792843e-03],
#        [-2.55187671e-03],
#        [-2.48576491e-03],
#        [-2.42425920e-03],
#        [-2.22505676e-03],
#        [-1.95378135e-03],
#        [-1.91698642e-03],
#        [-1.94329571e-03],
#        [-1.79010048e-03],
#        [-1.65424624e-03],
#        [-8.39201326e-04],
#        [-5.77463536e-04],
#        [-4.59329283e-04],
#        [-2.78470106e-04],
#        [-9.50098038e-05],
#        [ 3.93567374e-04],
#        [ 2.78413587e-04],
#        [ 2.71856610e-04],
#        [ 1.91709565e-04],
#        [-5.93527730e-05],
#        [-6.65305532e-04],
#        [-1.91186543e-03],
#        [-2.31978088e-03],
#        [-2.60392623e-03],
#        [-3.01032420e-03],
#        [-3.39818932e-03],
#        [-3.33860726e-03],
#        [-3.11006093e-03],
#        [-2.98116985e-03],
#        [-2.69520935e-03],
#        [-2.45926599e-03],
#        [-2.64302432e-03],
#        [-2.70244363e-03],
#        [-2.93104420e-03],
#        [-2.69672647e-03],
#        [-2.53757043e-03],
#        [-2.77584395e-03],
#        [-2.97222869e-03],
#        [-3.50098778e-03],
#        [-3.78025603e-03],
#        [-3.59037425e-03],
#        [-3.36556672e-03],
#        [-3.66683654e-03],
#        [-3.70666618e-03],
#        [-4.02432820e-03],
#        [-4.18760255e-03],
#        [-4.07775911e-03],
#        [-4.31028847e-03],
#        [-4.32120776e-03],
#        [-4.49139159e-03],
#        [-4.20518732e-03],
#        [-3.49077280e-03],
#        [-2.72867153e-03],
#        [-2.19479157e-03],
#        [-1.98740629e-03],
#        [-1.92148425e-03],
#        [-2.00393423e-03],
#        [-2.14862172e-03],
#        [-1.35782687e-03],
#        [-1.29867846e-03],
#        [-1.72271533e-03],
#        [-2.13903002e-03],
#        [-2.62018316e-03],
#        [-2.67971097e-03],
#        [-2.69756652e-03],
#        [-2.48741754e-03],
#        [-2.88547040e-03],
#        [-2.99750827e-03],
#        [-3.18029127e-03],
#        [-3.50326370e-03],
#        [-3.64247803e-03],
#        [-4.04231902e-03],
#        [-4.29861061e-03],
#        [-4.44782292e-03],
#        [-4.31313366e-03],
#        [-4.98411432e-03],
#        [-5.08011226e-03],
#        [-4.28102585e-03],
#        [-3.85826267e-03],
#        [-3.80036072e-03],
#        [-3.82658863e-03],
#        [-3.52699892e-03],
#        [-3.43769370e-03],
#        [-3.24404566e-03],
#        [-3.03961383e-03],
#        [-3.11550708e-03],
#        [-3.46665829e-03],
#        [-3.47752334e-03],
#        [-3.08532314e-03],
#        [-2.87726056e-03],
#        [-3.12994863e-03],
#        [-3.39935441e-03],
#        [-3.78399529e-03],
#        [-4.41240985e-03],
#        [-4.31971764e-03],
#        [-4.12677415e-03],
#        [-3.48895742e-03],
#        [-3.20437853e-03],
#        [-2.94310157e-03],
#        [-3.11298715e-03],
#        [-3.18367803e-03],
#        [-3.45397787e-03],
#        [-3.38163413e-03],
#        [-3.02918232e-03],
#        [-3.01016169e-03],
#        [-3.35044786e-03],
#        [-3.74554750e-03],
#        [-3.57923820e-03],
#        [-3.14078666e-03],
#        [-2.67740781e-03],
#        [-2.21725320e-03],
#        [-1.91311189e-03],
#        [-1.29588763e-03],
#        [-1.02068367e-03],
#        [-8.75020924e-04],
#        [-9.08618735e-04],
#        [-4.94606968e-04],
#        [-3.50217684e-04],
#        [-4.47813916e-04],
#        [-7.24210113e-04],
#        [-9.37800040e-04],
#        [-7.90294784e-04],
#        [-1.15347630e-03],
#        [-1.73778017e-03],
#        [-2.04032287e-03],
#        [-2.46105413e-03],
#        [-3.05855321e-03],
#        [-3.30693321e-03],
#        [-3.19868862e-03],
#        [-3.41439201e-03],
#        [-3.40179284e-03],
#        [-3.23006464e-03],
#        [-3.47941997e-03],
#        [-3.36968526e-03],
#        [-3.31243360e-03],
#        [-3.31392372e-03],
#        [-4.12536506e-03],
#        [-4.42525279e-03],
#        [-4.51046648e-03],
#        [-4.52932483e-03],
#        [-4.21656715e-03],
#        [-3.95778241e-03],
#        [-3.46752536e-03],
#        [-3.75592476e-03],
#        [-3.91413271e-03],
#        [-4.54037962e-03],
#        [-4.64006187e-03],
#        [-5.15508372e-03],
#        [-5.35621028e-03],
#        [-4.93371766e-03],
#        [-5.03258733e-03],
#        [-4.63792169e-03],
#        [-4.81384946e-03],
#        [-4.80778003e-03],
#        [-5.13102347e-03],
#        [-5.04854647e-03],
#        [-5.35686035e-03],
#        [-5.03963232e-03],
#        [-4.25371435e-03],
#        [-3.30552435e-03],
#        [-2.82225781e-03],
#        [-2.72953860e-03],
#        [-2.35226774e-03],
#        [-2.76367832e-03],
#        [-2.84531550e-03],
#        [-2.83697038e-03],
#        [-2.74270680e-03],
#        [-2.76522269e-03],
#        [-3.00262915e-03],
#        [-3.60920536e-03],
#        [-3.72072845e-03],
#        [-3.36892670e-03],
#        [-3.76922847e-03],
#        [-3.83523200e-03],
#        [-3.19584366e-03],
#        [-2.89741927e-03],
#        [-2.79521686e-03],
#        [-2.44821119e-03],
#        [-2.30626040e-03],
#        [-2.59108306e-03],
#        [-2.85818567e-03],
#        [-3.09561938e-03],
#        [-3.11518181e-03],
#        [-2.94692186e-03],
#        [-2.91297189e-03],
#        [-2.54618679e-03],
#        [-2.22345814e-03],
#        [-2.54491321e-03],
#        [-2.76747160e-03],
#        [-2.76077911e-03],
#        [-2.72677490e-03],
#        [-2.67765159e-03],
#        [-2.66052759e-03],
#        [-2.53580930e-03],
#        [-2.44631455e-03],
#        [-1.79278292e-03],
#        [-1.51248521e-03],
#        [-1.54765451e-03]], dtype=float32)

# %%
#Get rmse
#
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
rmse
# Out:
# 0.04132324917446681

# %%
#Mean Absolute Percentage Error - subtract from 100 and this is the accuracy? So like 97% which is pretty good
mape = np.mean(np.absolute((y_test- predictions)/y_test))* 100
mape
# Out:
# 116.69568073795782

# %%
# Visualising the results
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
plt.figure(figsize=(16,5))

plt.title('Model')
plt.xlabel('Date', fontsize=8)
plt.ylabel('Close Price USD ($)', fontsize=12)
plt.plot(train['TSLA_Return'])
plt.plot(valid[['TSLA_Return', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-25-7068682387ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
valid
# Out:
#             TSLA_Return  Predictions
# Date
# 2020-08-17     0.112031    -0.001894
# 2020-08-18     0.028028    -0.001030
# 2020-08-19    -0.004536    -0.000499
# 2020-08-20     0.065636    -0.000375
# 2020-08-21     0.024053    -0.000002
# ...                 ...          ...
# 2022-07-20     0.008023    -0.002536
# 2022-07-21     0.097805    -0.002446
# 2022-07-22     0.001975    -0.001793
# 2022-07-25    -0.013995    -0.001512
# 2022-07-26    -0.035664    -0.001548
#
# [489 rows x 2 columns]

# %% [markdown]
# ## Trying to predict using 30 days as timestep

# %%
train_data = scaled_data[0:training_data_len  , : ]

x_train = []
y_train = []
for i in range(30, len(train_data)):
    x_train.append(train_data[i-30:i, 0])
    y_train.append(train_data[i, 0])
    if i<=30:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.43890547, 0.49089033, 0.44730624, 0.39379086, 0.51776375,
#        0.50158155, 0.44734176, 0.42409039, 0.5361527 , 0.53796585,
#        0.46869402, 0.42801746, 0.44031328, 0.47293349, 0.45516775,
#        0.53724637, 0.49380036, 0.47183673, 0.51538453, 0.41759777,
#        0.45101867, 0.47574719, 0.48086899, 0.48909985, 0.50852862,
#        0.46210105, 0.36040624, 0.47643855, 0.50173638, 0.47549849])]
# [0.46462004100539717]

# %%
# converting into numpy sequences to train the LSTM model
x_train, y_train = np.array(x_train), np.array(y_train) 
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
print('Number of rows and columns: ', x_train.shape)
# Out:
# Number of rows and columns:  (1927, 30, 1)

# %%
x_train.shape
# Out:
# (1927, 30, 1)

# %%
model = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences = False))

model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(x_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 61/61 [==============================] - 5s 19ms/step - loss: 0.0215
# Epoch 2/50
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0059
# Epoch 3/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0059
# Epoch 4/50
# 61/61 [==============================] - 1s 22ms/step - loss: 0.0061
# Epoch 5/50
# 61/61 [==============================] - 1s 21ms/step - loss: 0.0058
# Epoch 6/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0061
# Epoch 7/50
# 61/61 [==============================] - 1s 21ms/step - loss: 0.0059
# Epoch 8/50
# 61/61 [==============================] - 1s 23ms/step - loss: 0.0061
# Epoch 9/50
# 61/61 [==============================] - 1s 23ms/step - loss: 0.0058
# Epoch 10/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0058
# Epoch 11/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 12/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0060
# Epoch 13/50
# 61/61 [==============================] - 2s 26ms/step - loss: 0.0058
# Epoch 14/50
# 61/61 [==============================] - 1s 22ms/step - loss: 0.0059
# Epoch 15/50
# 61/61 [==============================] - 1s 21ms/step - loss: 0.0059
# Epoch 16/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 17/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0058
# Epoch 18/50
# 61/61 [==============================] - 2s 25ms/step - loss: 0.0058
# Epoch 19/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0059
# Epoch 20/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 21/50
# 61/61 [==============================] - 1s 23ms/step - loss: 0.0058
# Epoch 22/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0058
# Epoch 23/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 24/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 25/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0062
# Epoch 26/50
# 61/61 [==============================] - 1s 22ms/step - loss: 0.0058
# Epoch 27/50
# 61/61 [==============================] - 1s 21ms/step - loss: 0.0058
# Epoch 28/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 29/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 30/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 31/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 32/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 33/50
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0058
# Epoch 34/50
# 61/61 [==============================] - 2s 25ms/step - loss: 0.0058
# Epoch 35/50
# 61/61 [==============================] - 2s 25ms/step - loss: 0.0058
# Epoch 36/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 37/50
# 61/61 [==============================] - 1s 18ms/step - loss: 0.0058
# Epoch 38/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 39/50
# 61/61 [==============================] - 1s 22ms/step - loss: 0.0058
# Epoch 40/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0059
# Epoch 41/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0060
# Epoch 42/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 43/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 44/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 45/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 46/50
# 61/61 [==============================] - 1s 20ms/step - loss: 0.0058
# Epoch 47/50
# 61/61 [==============================] - 1s 21ms/step - loss: 0.0058
# Epoch 48/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 49/50
# 61/61 [==============================] - 1s 18ms/step - loss: 0.0058
# Epoch 50/50
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0059

# %%
# Getting the predicted stock price
test_data = scaled_data[training_data_len - 30: , : ]

#Create the x_test and y_test data sets
x_test = []
y_test = dataset[training_data_len : , : ]
for i in range(30,len(test_data)):
    x_test.append(test_data[i-30:i,0])

# Convert x_test to a numpy array
x_test = np.array(x_test)

# %%
#Reshape the data into the shape accepted by the LSTM
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print('Number of rows and columns: ', x_test.shape)
# Out:
# Number of rows and columns:  (489, 30, 1)

# %%
# Making predictions using the test dataset
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
#Get rmse
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
rmse
# Out:
# 0.04111494638130117

# %%
#Mean Absolute Percentage Error
mape = np.mean(np.absolute((y_test- predictions)/y_test))* 100
mape
# Out:
# 101.18070581084044

# %%
# Visualising the results
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
plt.figure(figsize=(10,5))

plt.title('Model')
plt.xlabel('Date', fontsize=8)
plt.ylabel('Return', fontsize=12)
plt.plot(train['TSLA_Return'])
plt.plot(valid[['TSLA_Return', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-36-ab3c7b6acb65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
valid
# Out:
#             TSLA_Return  Predictions
# Date
# 2020-08-17     0.112031     0.000510
# 2020-08-18     0.028028     0.001592
# 2020-08-19    -0.004536     0.002198
# 2020-08-20     0.065636     0.002284
# 2020-08-21     0.024053     0.002725
# ...                 ...          ...
# 2022-07-20     0.008023    -0.000342
# 2022-07-21     0.097805    -0.000232
# 2022-07-22     0.001975     0.000612
# 2022-07-25    -0.013995     0.000929
# 2022-07-26    -0.035664     0.000850
#
# [489 rows x 2 columns]
